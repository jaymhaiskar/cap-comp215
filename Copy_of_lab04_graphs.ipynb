# %% [markdown]
# <a href="https://colab.research.google.com/github/jaymhaiskar/cap-comp215/blob/2024.01/Copy_of_lab04_graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# COMP 215 - LAB 4 (Graphs)
# -------------------------
# #### Name:
# #### Date:
#
# This lab exercise is an introduction to Graphs and Graph Analysis using [NetworkX](https://networkx.org/documentation/stable/).
#
# **New Python concepts**:
#   * **NetworkX** is an open-source package.  It provides a `Graph` object to represent a graph.
#   * Built-in `random` module provides algorithms for generating pseudo-random sequences
#   * [Generator expression](https://towardsdatascience.com/understanding-generator-expressions-in-python-fe0c4534619) - similar to a list comprehension, but faster and using much less memory!
#
# **Credits**:
#     Code examples based on [Think Complexity, 2nd edition](https://thinkcomplex.com).
#     Copyright 2016 Allen Downey, [MIT License](http://opensource.org/licenses/MIT)
#
# As usual, the first code cell simply imports all the modules we'll be using...

# %%
# %matplotlib inline

import math
import random
from timeit import timeit

import matplotlib.pyplot as plt
import networkx as nx

# %% [markdown]
# ## ER Graph algorithms.
#
# from the textbook...
# > One of the more interesting \[random graphs\] is the Erdős-Rényi model, studied by Paul Erdős and Alfréd Rényi in the 1960s.
#
# > An Erdős-Rényi graph (ER graph) is characterized by two parameters: $n$ is the number of nodes and $p$ is the probability that there is an edge between any two nodes.
#
# > Erdős and Rényi studied the properties of these random graphs; one of their surprising results is the existence of abrupt changes in the properties of random graphs as random edges are added.
#
# In this lab we will work towards re-producing this famous computational experiment.
#
# We can start will all the code we developed in class.
# Review development of these algorithms in teh `week04-graphs` workbook.

# %% [markdown]
# We `seed` Python's built-in random number generator so we get the same sequence each time (to facilitate debugging and comprehension!)  Comment this out and re-run the notebook when you are ready to run experiments.

# %%
random.seed(6) # Comment this out to run randomized experiments

# %%
def all_pairs(objects):
    """ Return a generator with the complete set of distinct object pairs, as 2-tuples, from the given iterable of objects """
    return ((a, b) for i in range(1, len(objects)) for a,b in zip(objects, objects[i:]))

# unit tests
assert set( all_pairs(('w', 'x', 'y', 'z')) ) == {('w', 'x'), ('x', 'y'), ('y', 'z'), ('w', 'y'), ('x', 'z'), ('w', 'z')}

# %%
def coin_toss(p=0.5):
    """ Simulate flipping a biased "coin", where the probability of 'heads' is p.  Return True iff 'heads', False otherwise """
    return random.random() < p

# %%
def random_pairs(objects, p=0.5):
    """ Return a generator of random subset of distinct object pairs (2-tuples), each with a probability of `p` """
    return (pair for pair in all_pairs(objects) if coin_toss(p))  # "flip a coin" to determine whether a given pair is included.

# Notice: no way to automate tests for random functions because they produce "side-effects" !!!
list( random_pairs(('w', 'x', 'y', 'z'), p=0.5) )
# Out:
# [('y', 'z'), ('w', 'y'), ('x', 'z')]

# %%
def make_random_graph(n, p):
    """ Return an ER Graph with n nodes, where the probability of an edge between a pair of nodes in p """
    graph = nx.Graph()
    labels = range(n)
    graph.add_nodes_from(labels)
    graph.add_edges_from(random_pairs(labels, p))
    return graph

# %%
N = 10
p = 0.2

random_graph = make_random_graph(N, p)

nx.draw_circular(random_graph,
                 node_color='#ff99dd',
                 node_size=1000,
                 with_labels=True)
plt.gca().set(
    title=f'Random Graph has {random_graph.number_of_nodes()} nodes and {random_graph.number_of_edges()} edges'
)
plt.show()

# %%
def reachable_nodes(graph, start):
    """ return the set of nodes that are reachable from the given start node"""
    seen = set()
    stack = [start]
    while stack:
        node = stack.pop()
        if node not in seen:
            seen.add(node)
            stack.extend(graph.neighbors(node))
    return seen

# %%
def is_connected(graph):
    """ Return True if the graph is connected, false otherwise. """
    start = next(iter(graph))   # grab the first node in the graph.  This statement will need some further explanation.
    reachable = reachable_nodes(graph, start)
    return len(reachable) == len(graph)

# %%
is_connected(random_graph)
# Out:
# False

# %% [markdown]
# ## Lab Exercises
#
# ### Exercise 1
# Use `timeit` to run an experiment that times the `reachable_nodes` algorithm.
# Once you understand how `timeit` works, design a small experiment to time the `reachable_nodes` algorithm for a range of graph sizes (`n`)
# Plot the results of your experiment, where x = graph size (`n`) and y = avg. execution time in seconds

# %%
# here's an example of how to use timeit:
N = 100
p = 1
g = make_random_graph(N, p)  # when p=1, this is a complete graph!
seconds = timeit(lambda: reachable_nodes( g,  0),  number=3)
f'Avg. time to execute: {seconds} seconds'
# Out:
# 'Avg. time to execute: 0.001518910000015694 seconds'

# %%
# I used ChatGPT to build the skeleton of this function

def measure_execution_time(N, p, source_node):
    g = make_random_graph(N, p)
    seconds = timeit(lambda: reachable_nodes(g, source_node), number=3) #took from your code above
    return seconds

graph_sizes = [10, 20, 30, 40, 50]
avg_execution_times = []

for size in graph_sizes:
    avg_time = measure_execution_time(size, 0.5, 0)  # Sample p=0.5, source node=0
    avg_execution_times.append(avg_time)
    print(f"Graph size: {size}, Avg. time to execute: {avg_time} seconds")


plt.plot(graph_sizes, avg_execution_times, marker='o')
plt.xlabel('Graph Size (n)')
plt.ylabel('Avg. Execution Time (seconds)')
plt.title('Execution Time of reachable_nodes Algorithm vs. Graph Size')
plt.grid(True)
plt.show()
# Out:
# Graph size: 10, Avg. time to execute: 3.8119999999253196e-05 seconds
# Graph size: 20, Avg. time to execute: 0.00010141000001340217 seconds
# Graph size: 30, Avg. time to execute: 0.00013059000002613175 seconds
# Graph size: 40, Avg. time to execute: 0.00015780000001086592 seconds
# Graph size: 50, Avg. time to execute: 0.00024056000000882705 seconds

# %% [markdown]
# ### Exercise 2:
# What is the **Big-O time complexity** of the `reachable_nodes` algorithm?

# %%
"""Let n be the number of nodes in the graph and m be the number of edges.

the while loop in the function will run n times, as it will stop after running out of nodes

The algorithm checks every edge, to check if it's neighbours are connected. so O(m).

The time complexity is O(n+m) as these are the two things the codes checks, so the time required for the
code to run depends on the amount of nodes AND edges

"""
# Out:
# "Let n be the number of nodes in the graph and m be the number of edges.\n\nthe while loop in the function will run n times, as it will stop after running out of nodes\n\nThe algorithm checks every edge, to check if it's neighbours are connected. so O(m).\n\nThe time complexity is O(n+m) as these are the two things the codes checks, so the time required for the\ncode to run depends on the amount of nodes AND edges\n\n"

# %% [markdown]
# #### Ex. 2 Your Answer:

# %% [markdown]
# ## Likelihood of connectivity
#
# We are ready to replicate Erdős and Rényi's computational experiment.
# In this experiment, we estimate the likelihood that a randomly-generated ER graph is connected.
#
# Like most computational experiments, we simple "brute force" the solution - create a big pile of ER graphs, and simply count up how many of them are connected.
#
# ### Exercise 3:
# Write a function that runs one ER experiment for a given value of $n$ and $p$.
#
# The function generates `n_trials` (number of trials) graphs and returns the proportion of them that are connected.

# %%
def proportion_connected(n, p, n_trials=100):
    """ Return the proportion of random ER Graphs (n, p) that are connected out of n trials. """
    # Ex. 3 your code here here...
    count=0

    for trial in range(n_trials):

      graph=make_random_graph(n,p)

      if is_connected(graph):
          count= count + 1

    return count

    # Step 1: make n_trials random graphs

    # Step 2: compute the proportion of those graphs that are connected


n = 30
p = 0.1
p_connected = proportion_connected(n, p)
f'Likelihood that an ER graph (n={n}, p={p}) is connected: {p_connected:.1f}%'
# Out:
# 'Likelihood that an ER graph (n=30, p=0.1) is connected: 18.0%'

# %% [markdown]
# ### Exercise 4:
# Use `timeit` to determine how much time each experimental run is consuming.
# Plot the results of your experiment, where x = number of trials (`n_trials`) and y = avg. execution time in seconds

# %%
#updated function from above with timer
def proportion_connected(n, p, n_trials=100):
    """ Return the proportion of random ER Graphs (n, p) that are connected out of n trials. """
    count=0
    for trial in range(n_trials):
      graph=make_random_graph(n,p)

      if is_connected(graph):
          count= count + 1

      return count

execution_times = []
trials=[]

for i in range(100):
  trials.append(i)

for t in trials:
  seconds = timeit(lambda: proportion_connected(n, p), number=3) #took from your code above
  execution_times.append(seconds)



# print(execution_times)


plt.plot(trials, execution_times, marker='o')
plt.xlabel('Number of Trials (n_trials)')
plt.ylabel('Avg. Execution Time (seconds)')
plt.title('Execution Time vs. Number of Trials')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Exercise 5:
# Our experimental results are more accurate (i.e., show less variation between runs) when we use large values for `n` and `n_trials`.  But we've seen that large values for these 2 inputs can cause serious performance issues.
#
# What are reasonable value for `n` and `n_trials` to use in the experimental setup below?

# %% [markdown]
# #### Your Answer:

# %% [markdown]
# ## Critical Value of $p$
#
# Near a "critical value" of $p$, the likelihood of a random graph being connected rapidly changes from near 0 to near 1.
# Erdős and Rényi predict the critical value should be:  $ln(n) / n$
# For example...

# %%
n = 19699
f'Erdős and Rényi predict the critical value of p for graphs of size {n} = {math.log(n) / n:0.3f}'

print(n, " is the highest number that will get the probablty the lowest, of 0.001")
# Out:
# 19699  is the highest number that will get the probablty the lowest, of 0.001

# %% [markdown]
# ### Exercise 6:
# Develop an experiment using `proportion_connected` that runs trials over a range of values for $p$.
# The goal of this experiment is to identify the "critical value" of $p$ for graphs of size $n$.
#
# You can conduct this experiment by hand by manually running the code above with different input values and record your results in Ex. 7, ... or
#
# #### Challenge - Take your skills to the next level...
# Develop the experimental setup in code to run all trials over a range of values for $p$ and then plot the results of your experiment, where x = value of `p` and y = proportion connection in the experimental run

# %%
# Ex. 6 (challenge) your code here...

# %% [markdown]
# ### Exercise 7:
# Does your experiment confirm or refute Erdős and Rényi's results?
#
# What real-world applications / implications might this understanding of graph connectivity have?

# %%
'''
My experiment confirm Erdős and Rényi's results.

Some real world application os graph nconnectviity is the transportation city of cities, and the apps needed to navigate through those networks.

'''

# %% [markdown]
# #### Ex. 7 Your Answer:
